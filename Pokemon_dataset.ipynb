# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[["Name","Generation"]]
# Out:
#                       Name  Generation
# 0                Bulbasaur           1
# 1                  Ivysaur           1
# 2                 Venusaur           1
# 3    VenusaurMega Venusaur           1
# 4               Charmander           1
# ..                     ...         ...
# 795                Diancie           6
# 796    DiancieMega Diancie           6
# 797    HoopaHoopa Confined           6
# 798     HoopaHoopa Unbound           6
# 799              Volcanion           6
#
# [800 rows x 2 columns]

# %%
df.iloc[:10]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df[(df["HP"]>70) & (df["Speed"]>80) & (df["Legendary"]==True)]
# Out:
#        #                      Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144                  Articuno       Ice    Flying   90      85      100
# 157  145                    Zapdos  Electric    Flying   90      90       85
# 158  146                   Moltres      Fire    Flying   90     100       90
# 162  150                    Mewtwo   Psychic       NaN  106     110       90
# 163  150       MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# 164  150       MewtwoMega Mewtwo Y   Psychic       NaN  106     150       70
# 262  243                    Raikou  Electric       NaN   90      85       75
# 263  244                     Entei      Fire       NaN  115     115       85
# 264  245                   Suicune     Water       NaN  100      75      115
# 269  249                     Lugia   Psychic    Flying  106      90      130
# 270  250                     Ho-oh      Fire    Flying  106     130       90
# ...

# %%
for index,row in df.iterrows():
    print(index,row["Type 1"])
# Out:
# 0 Grass
# 1 Grass
# 2 Grass
# 3 Grass
# 4 Fire
# 5 Fire
# 6 Fire
# 7 Fire
# 8 Fire
# 9 Water
# 10 Water
# 11 Water
# 12 Water
# 13 Bug
# 14 Bug
# 15 Bug
# 16 Bug
# 17 Bug
# 18 Bug
# 19 Bug
# 20 Normal
# 21 Normal
# 22 Normal
# 23 Normal
# 24 Normal
# 25 Normal
# 26 Normal
# 27 Normal
# 28 Poison
# 29 Poison
# 30 Electric
# 31 Electric
# 32 Ground
# 33 Ground
# 34 Poison
# 35 Poison
# 36 Poison
# 37 Poison
# 38 Poison
# 39 Poison
# 40 Fairy
# 41 Fairy
# 42 Fire
# 43 Fire
# 44 Normal
# 45 Normal
# 46 Poison
# 47 Poison
# 48 Grass
# 49 Grass
# 50 Grass
# 51 Bug
# 52 Bug
# 53 Bug
# 54 Bug
# 55 Ground
# 56 Ground
# 57 Normal
# 58 Normal
# 59 Water
# 60 Water
# 61 Fighting
# 62 Fighting
# 63 Fire
# 64 Fire
# 65 Water
# 66 Water
# 67 Water
# 68 Psychic
# 69 Psychic
# 70 Psychic
# 71 Psychic
# 72 Fighting
# 73 Fighting
# 74 Fighting
# 75 Grass
# 76 Grass
# 77 Grass
# 78 Water
# 79 Water
# 80 Rock
# 81 Rock
# 82 Rock
# 83 Fire
# 84 Fire
# 85 Water
# 86 Water
# 87 Water
# 88 Electric
# ...

# %%
df.loc[(df["Type 1"]=="Water") & (df["Legendary"]==True)]
# Out:
#        #                 Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 264  245              Suicune  Water     NaN  100      75      115       90
# 421  382               Kyogre  Water     NaN  100     100       90      150
# 422  382  KyogrePrimal Kyogre  Water     NaN  100     150       90      180
# 541  484               Palkia  Water  Dragon   90     120      100      150
#
#      Sp. Def  Speed  Generation  Legendary
# 264      115     85           2       True
# 421      140     90           3       True
# 422      160     90           3       True
# 541      120    100           4       True

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df["HP"].max()
# Out:
# 255

# %%
df.sort_values(["HP","Attack"],ascending=[0,0])
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 230  213    Shuckle      Bug   Rock   20      10      230       10      230
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %%
df1 = df

# %%
df["Total"] = df["HP"] + df["Attack"] + df["Defense"] + df["Sp. Atk"] +df["Sp. Def"] +df["Speed"]
# df[Total] = df.iloc[:,4:10].sum(axis=1)

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df.loc[df["Total"] == df["Total"].max()]
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 163      154      100    130           1       True    780
# 164      194      120    140           1       True    780
# 426      180      100    115           3       True    780

# %%
df = df.drop(columns=["Generation"])
df.head(11)
# Out:
#     #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0   1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1   2                    Ivysaur  Grass  Poison  60      62       63       80
# 2   3                   Venusaur  Grass  Poison  80      82       83      100
# 3   3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4   4                 Charmander   Fire     NaN  39      52       43       60
# 5   5                 Charmeleon   Fire     NaN  58      64       58       80
# 6   6                  Charizard   Fire  Flying  78      84       78      109
# 7   6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8   6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9   7                   Squirtle  Water     NaN  44      48       65       50
# 10  8                  Wartortle  Water     NaN  59      63       80       65
#
# ...

# %%
cols = list(df.columns.values)

df = df[cols[:10] + [cols[-1]] + [cols[-2]]]

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Legendary
# 0         65       65     45    318      False
# ...

# %%
#Rename Columns
df = df.rename(columns={"Total":"Total Stats"})

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total Stats  Legendary
# 0         65       65     45          318      False
# ...

# %%
legendary_vs_normal = df.groupby("Legendary")[cols[4:10]]

print(x.median())
# Out:
#            HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Legendary
# False      65      72       66       65       65     64
# True       91     110      100      120      100    100

# %%
pokemon_attributes = df.groupby("Legendary").agg({"Name":"count","HP":"median","Attack":"mean","Defense":"max",
                                            "Speed":"max","Total Stats":"median"})

pokemon_attributes
# Out:
#            Name  HP      Attack  Defense  Speed  Total Stats
# Legendary
# False       735  65   75.669388      230    160          425
# True         65  91  116.676923      200    180          600

# %%
pokemon_attributes = pokemon_attributes.rename(columns = {"Name":"# of pokemons","HP":"HP(Median)","Attack":"Attack(Mean)","Defense":"(Max)Defense",
                                     "Speed":"(Max)Speed","Total Stats":"Total Stats(Median)"})

# %%
pokemon_attributes
# Out:
#            # of pokemons  HP(Median)  Attack(Mean)  (Max)Defense  (Max)Speed  \
# Legendary
# False                735          65     75.669388           230         160
# True                  65          91    116.676923           200         180
#
#            Total Stats(Median)
# Legendary
# False                      425
# True                       600

# %%
print(df["Name"].unique())
# Out:
# ['Bulbasaur' 'Ivysaur' 'Venusaur' 'VenusaurMega Venusaur' 'Charmander'
#  'Charmeleon' 'Charizard' 'CharizardMega Charizard X'
#  'CharizardMega Charizard Y' 'Squirtle' 'Wartortle' 'Blastoise'
#  'BlastoiseMega Blastoise' 'Caterpie' 'Metapod' 'Butterfree' 'Weedle'
#  'Kakuna' 'Beedrill' 'BeedrillMega Beedrill' 'Pidgey' 'Pidgeotto'
#  'Pidgeot' 'PidgeotMega Pidgeot' 'Rattata' 'Raticate' 'Spearow' 'Fearow'
#  'Ekans' 'Arbok' 'Pikachu' 'Raichu' 'Sandshrew' 'Sandslash'
#  'Nidoran (Female)' 'Nidorina' 'Nidoqueen' 'Nidoran (Male)' 'Nidorino'
#  'Nidoking' 'Clefairy' 'Clefable' 'Vulpix' 'Ninetales' 'Jigglypuff'
#  'Wigglytuff' 'Zubat' 'Golbat' 'Oddish' 'Gloom' 'Vileplume' 'Paras'
#  'Parasect' 'Venonat' 'Venomoth' 'Diglett' 'Dugtrio' 'Meowth' 'Persian'
#  'Psyduck' 'Golduck' 'Mankey' 'Primeape' 'Growlithe' 'Arcanine' 'Poliwag'
#  'Poliwhirl' 'Poliwrath' 'Abra' 'Kadabra' 'Alakazam'
#  'AlakazamMega Alakazam' 'Machop' 'Machoke' 'Machamp' 'Bellsprout'
# ...

# %%
print(df["HP"].value_counts().max())
# Out:
# 67

# %%
df.to_csv("Modified Dataset.csv",index=False)

# %%
pokemon_attributes.to_csv("Pokemon_stats.csv",index=False)
